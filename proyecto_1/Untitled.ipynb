# %%
import yfinance as yf
import pandas as pd
df = yf.download("AMXL.MX", start="2023-01-01", end="2024-01-01")
# Out:
# $AMXL.MX: possibly delisted; no timezone found
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AMXL.MX']: possibly delisted; no timezone found
