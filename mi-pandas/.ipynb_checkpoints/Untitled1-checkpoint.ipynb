# %%
import pandas as pd

df = pd.read_excel("cpv2020_b_bc_07_educacion copy.xlsx", sheet_name=4, header=5)

# %%
df.columns
# Out:
# Index(['Entidad federativa', 'Municipio', 'Sexo',
#        'Grupos quinquenales de edad', 'Población de 15 años y más',
#        'Condición de alfabetismo', 'Unnamed: 6', 'Unnamed: 7'],
#       dtype='str')

# %%
df["Municipio"]
# Out:
# 0              NaN
# 1              NaN
# 2            Total
# 3            Total
# 4            Total
#           ...
# 333    004 Tijuana
# 334    004 Tijuana
# 335    004 Tijuana
# 336    004 Tijuana
# 337    004 Tijuana
# Name: Municipio, Length: 338, dtype: str

# %%
len(df["Municipio"])
# Out:
# 338

# %%
set(df["Municipio"])
# Out:
# {'001 Ensenada',
#  '002 Mexicali',
#  '003 Tecate',
#  '004 Tijuana',
#  '005 Playas de Rosarito',
#  '006 San Quintín',
#  'Total',
#  nan}

# %%
set(df["Sexo"])
# Out:
# {'Hombres', 'Mujeres', 'Total', nan}

# %%
df[["Municipio", "Sexo"]]
# Out:
#        Municipio     Sexo
# 0            NaN      NaN
# 1            NaN      NaN
# 2          Total    Total
# 3          Total    Total
# 4          Total    Total
# ..           ...      ...
# 333  004 Tijuana  Mujeres
# 334  004 Tijuana  Mujeres
# 335  004 Tijuana  Mujeres
# 336  004 Tijuana  Mujeres
# 337  004 Tijuana  Mujeres
#
# [338 rows x 2 columns]

# %%
df[["Municipio", "Condición de alfabetismo"]]
# Out:
#        Municipio Condición de alfabetismo
# 0            NaN                 Alfabeta
# 1            NaN                      NaN
# 2          Total                  2817601
# 3          Total                   312343
# 4          Total                   335947
# ..           ...                      ...
# 333  004 Tijuana                    21033
# 334  004 Tijuana                    14120
# 335  004 Tijuana                     8569
# 336  004 Tijuana                     5377
# 337  004 Tijuana                     4044
#
# [338 rows x 2 columns]

# %%
df["Condición de alfabetismo"].describe()
# Out:
# count      337
# unique     336
# top       1394
# freq         2
# Name: Condición de alfabetismo, dtype: int64

# %%
df.iloc[51]
# Out:
# Entidad federativa             02 Baja California
# Municipio                            001 Ensenada
# Sexo                                        Total
# Grupos quinquenales de edad            15-19 años
# Población de 15 años y más                36228.0
# Condición de alfabetismo                    35866
# Unnamed: 6                                    227
# Unnamed: 7                                    135
# Name: 51, dtype: object

# %%
df.head()
# Out:
#    Entidad federativa Municipio   Sexo Grupos quinquenales de edad  \
# 0                 NaN       NaN    NaN                         NaN
# 1                 NaN       NaN    NaN                         NaN
# 2  02 Baja California     Total  Total                       Total
# 3  02 Baja California     Total  Total                  15-19 años
# 4  02 Baja California     Total  Total                  20-24 años
#
#    Población de 15 años y más Condición de alfabetismo  Unnamed: 6  \
# 0                         NaN                 Alfabeta  Analfabeta
# 1                         NaN                      NaN         NaN
# 2                   2882498.0                  2817601       52496
# 3                    315639.0                   312343        1595
# 4                    340359.0                   335947        2046
#
#         Unnamed: 7
# 0  No especificado
# 1              NaN
# 2            12401
# 3             1701
# 4             2366

# %%
df[df["Sexo"]=="Mujeres"]
# Out:
#      Entidad federativa    Municipio     Sexo Grupos quinquenales de edad  \
# 34   02 Baja California        Total  Mujeres                       Total
# 35   02 Baja California        Total  Mujeres                  15-19 años
# 36   02 Baja California        Total  Mujeres                  20-24 años
# 37   02 Baja California        Total  Mujeres                  25-29 años
# 38   02 Baja California        Total  Mujeres                  30-34 años
# ..                  ...          ...      ...                         ...
# 333  02 Baja California  004 Tijuana  Mujeres                  65-69 años
# 334  02 Baja California  004 Tijuana  Mujeres                  70-74 años
# 335  02 Baja California  004 Tijuana  Mujeres                  75-79 años
# 336  02 Baja California  004 Tijuana  Mujeres                  80-84 años
# 337  02 Baja California  004 Tijuana  Mujeres               85 años y más
#
#      Población de 15 años y más Condición de alfabetismo Unnamed: 6 Unnamed: 7
# ...

# %%
#El municipio es mexicali Y El sexo es mujeres
df[(df["Municipio"]=="002 Mexicali") & (df["Sexo"]=="Mujeres") ]
# Out:
#      Entidad federativa     Municipio     Sexo Grupos quinquenales de edad  \
# 130  02 Baja California  002 Mexicali  Mujeres                       Total
# 131  02 Baja California  002 Mexicali  Mujeres                  15-19 años
# 132  02 Baja California  002 Mexicali  Mujeres                  20-24 años
# 133  02 Baja California  002 Mexicali  Mujeres                  25-29 años
# 134  02 Baja California  002 Mexicali  Mujeres                  30-34 años
# 135  02 Baja California  002 Mexicali  Mujeres                  35-39 años
# 136  02 Baja California  002 Mexicali  Mujeres                  40-44 años
# 137  02 Baja California  002 Mexicali  Mujeres                  45-49 años
# 138  02 Baja California  002 Mexicali  Mujeres                  50-54 años
# 139  02 Baja California  002 Mexicali  Mujeres                  55-59 años
# 140  02 Baja California  002 Mexicali  Mujeres                  60-64 años
# ...

# %%
#El municipio es mexicali o El sexo es mujeres
df[(df["Municipio"]=="002 Mexicali") | (df["Sexo"]=="Mujeres") ]
# Out:
#      Entidad federativa    Municipio     Sexo Grupos quinquenales de edad  \
# 34   02 Baja California        Total  Mujeres                       Total
# 35   02 Baja California        Total  Mujeres                  15-19 años
# 36   02 Baja California        Total  Mujeres                  20-24 años
# 37   02 Baja California        Total  Mujeres                  25-29 años
# 38   02 Baja California        Total  Mujeres                  30-34 años
# ..                  ...          ...      ...                         ...
# 333  02 Baja California  004 Tijuana  Mujeres                  65-69 años
# 334  02 Baja California  004 Tijuana  Mujeres                  70-74 años
# 335  02 Baja California  004 Tijuana  Mujeres                  75-79 años
# 336  02 Baja California  004 Tijuana  Mujeres                  80-84 años
# 337  02 Baja California  004 Tijuana  Mujeres               85 años y más
#
#      Población de 15 años y más Condición de alfabetismo Unnamed: 6 Unnamed: 7
# ...

# %%
df[df["Población de 15 años y más"]> 152806]
# Out:
#      Entidad federativa     Municipio     Sexo Grupos quinquenales de edad  \
# 2    02 Baja California         Total    Total                       Total
# 3    02 Baja California         Total    Total                  15-19 años
# 4    02 Baja California         Total    Total                  20-24 años
# 5    02 Baja California         Total    Total                  25-29 años
# 6    02 Baja California         Total    Total                  30-34 años
# 7    02 Baja California         Total    Total                  35-39 años
# 8    02 Baja California         Total    Total                  40-44 años
# 9    02 Baja California         Total    Total                  45-49 años
# 10   02 Baja California         Total    Total                  50-54 años
# 11   02 Baja California         Total    Total                  55-59 años
# 18   02 Baja California         Total  Hombres                       Total
# ...

# %%
df[df["Municipio"].str.startswith("T")]
# Out:
#     Entidad federativa Municipio     Sexo Grupos quinquenales de edad  \
# 2   02 Baja California     Total    Total                       Total
# 3   02 Baja California     Total    Total                  15-19 años
# 4   02 Baja California     Total    Total                  20-24 años
# 5   02 Baja California     Total    Total                  25-29 años
# 6   02 Baja California     Total    Total                  30-34 años
# 7   02 Baja California     Total    Total                  35-39 años
# 8   02 Baja California     Total    Total                  40-44 años
# 9   02 Baja California     Total    Total                  45-49 años
# 10  02 Baja California     Total    Total                  50-54 años
# 11  02 Baja California     Total    Total                  55-59 años
# 12  02 Baja California     Total    Total                  60-64 años
# 13  02 Baja California     Total    Total                  65-69 años
# ...

# %%
df[df["Municipio"].str.endswith("i")]
# Out:
#      Entidad federativa     Municipio     Sexo Grupos quinquenales de edad  \
# 98   02 Baja California  002 Mexicali    Total                       Total
# 99   02 Baja California  002 Mexicali    Total                  15-19 años
# 100  02 Baja California  002 Mexicali    Total                  20-24 años
# 101  02 Baja California  002 Mexicali    Total                  25-29 años
# 102  02 Baja California  002 Mexicali    Total                  30-34 años
# 103  02 Baja California  002 Mexicali    Total                  35-39 años
# 104  02 Baja California  002 Mexicali    Total                  40-44 años
# 105  02 Baja California  002 Mexicali    Total                  45-49 años
# 106  02 Baja California  002 Mexicali    Total                  50-54 años
# 107  02 Baja California  002 Mexicali    Total                  55-59 años
# 108  02 Baja California  002 Mexicali    Total                  60-64 años
# ...
